# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import signal, interpolate

# %%
with open("2020-03-25 12_23_37.804528_yokoyama_C40.binaryfile", 'rb') as f:
    X = pickle.load(f)

# %%
plt.figure(figsize=(16, 8))
plt.plot(X[:, 0])
plt.plot(X[:, 32] * 10)

# %%
X.shape
# Out:
# (13903, 33)

# %%
np.count_nonzero(X[:, 32] == 1)
# Out:
# 40

# %%
X[:, :33]
# Out:
# array([[  2.004, 157.417, 114.37 , ...,  79.702, 548.125,   1.   ],
#        [  2.004, 157.417, 114.37 , ...,  79.702, 548.125,   0.   ],
#        [  2.004, 157.417, 114.37 , ...,  79.702, 548.125,   0.   ],
#        ...,
#        [  6.167, 174.238, 185.801, ..., 138.848, 287.274,   0.   ],
#        [  2.549, 197.981, 186.583, ..., 105.71 , 319.59 ,   0.   ],
#        [  2.549, 197.981, 186.583, ..., 105.71 , 319.59 ,   0.   ]])

# %%
# fir filter
b = signal.firwin(256, [1.5/64, 10.0/64], pass_zero=False)
X[:, :32] = signal.filtfilt(b, 1, X[:, :32], axis=0)
X.shape
# Out:
# (13903, 33)

# %%
plt.figure(figsize=(16, 8))
plt.plot(X[0:2048, 0])
plt.plot(X[0:2048, -1] * 100)
plt.ylim(-25,25)
# Out:
# (-25, 25)
