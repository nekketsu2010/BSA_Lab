# %%
import numpy as np
import pandas as pd

import seaborn as sns
sns.set(font='Yu Gothic')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv = pd.read_csv("emotiv_epoc_plus.csv")
csv
# Out:
#                time       AF3        F7        F3       FC5        T7  \
# 0      1.601645e+09  4323.077  4787.692  3944.103  4726.667  4032.821
# 1      1.601645e+09  4324.615  4786.667  3944.615  4724.615  4032.308
# 2      1.601645e+09  4322.564  4786.667  3945.641  4723.590  4033.846
# 3      1.601645e+09  4323.077  4788.205  3944.615  4725.128  4033.333
# 4      1.601645e+09  4326.154  4786.667  3944.615  4724.615  4032.821
# ...             ...       ...       ...       ...       ...       ...
# 23035  1.601645e+09  4326.667  4788.205  3944.615  4725.128  4028.718
# 23036  1.601645e+09  4326.667  4787.692  3943.590  4725.641  4032.821
# 23037  1.601645e+09  4325.641  4788.205  3943.077  4724.103  4034.359
# 23038  1.601645e+09  4323.077  4787.179  3943.590  4725.128  4034.359
# 23039  1.601645e+09  4323.590  4786.667  3944.103  4727.692  4035.385
#
#              P7        O1        O2        P8        T8       FC6        F4  \
# 0      4638.462  4255.897  4411.282  4383.077  4140.000  4398.462  3786.667
# 1      4636.923  4252.308  4411.282  4379.487  4143.590  4396.410  3789.744
# 2      4635.385  4254.359  4411.795  4379.487  4144.103  4400.513  3789.744
# 3      4635.897  4256.923  4410.769  4383.077  4143.077  4403.590  3786.667
# 4      4635.897  4255.897  4410.769  4381.538  4142.564  4399.487  3789.231
# ...         ...       ...       ...       ...       ...       ...       ...
# 23035  4636.410  4256.410  4409.744  4382.051  4143.590  4398.462  3785.128
# 23036  4635.385  4254.359  4411.795  4383.077  4147.179  4400.513  3788.718
# 23037  4635.897  4254.359  4412.821  4383.590  4143.590  4401.538  3788.205
# 23038  4635.897  4255.897  4410.256  4383.590  4140.000  4401.538  3786.154
# 23039  4636.923  4257.436  4409.744  4384.103  4141.026  4398.974  3786.667
#
#              F8       AF4
# 0      3916.410  4364.615
# 1      3918.974  4366.154
# 2      3917.949  4369.231
# 3      3917.436  4368.718
# 4      3920.513  4367.179
# ...         ...       ...
# 23035  3917.436  4366.667
# 23036  3918.974  4368.205
# 23037  3918.462  4366.667
# 23038  3917.949  4366.154
# 23039  3918.974  4367.692
#
# [23040 rows x 15 columns]

# %%
AF3 = csv['AF3'].values
AF3
# Out:
# array([4323.077, 4324.615, 4322.564, ..., 4325.641, 4323.077, 4323.59 ])

# %%
plt.figure(figsize=(16, 8))
# tt = np.linspace(0, 128, AF3.shape[0])
plt.plot(AF3)
plt.xlim(0, 256)
plt.show()

# %%
AF3_FFT = np.abs(np.square(np.fft.fft(AF3)))
plt.figure(figsize=(16, 8))
tt = np.linspace(0, 128, AF3_FFT.shape[0])
plt.plot(tt, AF3_FFT)
plt.xlim(0, 64)
plt.ylim(0, 0.3*10**7)
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# ## α波収録

# %%
csv = pd.read_csv("alphawave_emotiv_epoc_plus.csv")
csv
# Out:
#                time       AF3        F7        F3       FC5        T7  \
# 0      1.603035e+09  4302.564  4785.641  3928.718  4736.410  3935.385
# 1      1.603035e+09  4296.410  4785.128  3923.590  4736.923  3937.949
# 2      1.603035e+09  4288.718  4781.538  3914.359  4733.333  3936.923
# 3      1.603035e+09  4286.667  4783.077  3910.769  4732.308  3938.462
# 4      1.603035e+09  4294.872  4784.615  3916.410  4735.897  3939.487
# ...             ...       ...       ...       ...       ...       ...
# 23035  1.603036e+09  4309.744  4787.179  3918.974  4712.821  4004.103
# 23036  1.603036e+09  4301.538  4784.615  3918.462  4707.179  4003.590
# 23037  1.603036e+09  4300.513  4783.077  3918.974  4706.154  3997.949
# 23038  1.603036e+09  4303.590  4783.590  3916.923  4705.641  3995.897
# 23039  1.603036e+09  4299.487  4783.590  3914.872  4705.128  3996.923
#
#              P7        O1        O2        P8        T8       FC6        F4  \
# 0      4605.128  4309.231  4407.179  4445.641  4130.256  4385.128  3767.179
# 1      4607.179  4311.795  4403.590  4445.641  4126.154  4386.154  3763.590
# 2      4604.615  4305.641  4402.051  4446.667  4124.615  4380.513  3755.897
# 3      4603.077  4306.154  4402.564  4445.641  4123.077  4373.846  3749.744
# 4      4604.103  4310.769  4404.615  4450.256  4126.667  4380.000  3753.846
# ...         ...       ...       ...       ...       ...       ...       ...
# 23035  4608.718  4298.462  4400.000  4399.487  4129.744  4338.974  3776.923
# 23036  4611.282  4298.462  4409.744  4411.795  4138.974  4344.615  3782.051
# 23037  4609.231  4297.436  4412.308  4414.872  4140.513  4350.256  3787.179
# 23038  4609.744  4294.872  4407.692  4410.256  4135.385  4345.128  3784.615
# 23039  4611.795  4294.872  4401.538  4407.692  4130.769  4335.897  3777.949
#
#              F8       AF4
# 0      4241.026  4344.615
# 1      4244.615  4337.949
# 2      4241.026  4325.641
# 3      4235.897  4321.538
# 4      4243.590  4332.308
# ...         ...       ...
# 23035  2688.718  4361.538
# 23036  2690.256  4358.462
# 23037  2687.692  4360.000
# 23038  2681.538  4361.026
# 23039  2665.641  4353.846
#
# [23040 rows x 15 columns]

# %%
O1 = csv['O2'].values
O1
# Out:
# array([4407.179, 4403.59 , 4402.051, ..., 4412.308, 4407.692, 4401.538])

# %%
plt.figure(figsize=(16, 8))
# tt = np.linspace(0, 128, AF3.shape[0])
plt.plot(O1)
plt.xlim(0, 5120)
plt.show()

# %%
O1_FFT = np.abs(np.square(np.fft.fft(O1)))
plt.figure(figsize=(16, 8))
tt = np.linspace(0, 128, O1_FFT.shape[0])
plt.plot(tt, O1_FFT)
plt.xlim(0, 64)
plt.ylim(0, 0.3*10**9)
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.show()

# %%
from scipy import signal
Fs = 128
# firフィルタを適用する
def firFilter(x):
    # fir filter
    b = signal.firwin(Fs * 2 - 1, [1.5/(Fs/2), 15.0/(Fs/2)], pass_zero=False)
    x = signal.filtfilt(b, 1, x)
    return x

# %%
O1 = firFilter(O1)
O1
# Out:
# array([ 0.02533113, -0.75773907, -1.39207761, ...,  2.81068865,
#         1.96243338,  0.02529871])

# %%
plt.figure(figsize=(16, 8))
# tt = np.linspace(0, 128, AF3.shape[0])
plt.plot(O1)
plt.xlim(12000, 13500)
# plt.xticks(np.arange(0, O1.shape[0]+1, 1000))
plt.show()

# %%
O1_FFT = np.abs(np.square(np.fft.fft(O1[19200:23040])))
plt.figure(figsize=(16, 8))
tt = np.linspace(0, 128, O1_FFT.shape[0])
plt.plot(tt, O1_FFT)
plt.xlim(0, 15)
# plt.ylim(0, 0.3*10**7)
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.show()

# %%
O1_FFT = np.abs(np.square(np.fft.fft(O1[12000:15840])))
plt.figure(figsize=(16, 8))
tt = np.linspace(0, 128, O1_FFT.shape[0])
plt.plot(tt, O1_FFT)
plt.xlim(0, 15)
# plt.ylim(0, 2.0*10**6)
plt.xlabel("Frequency[Hz]")
plt.ylabel("Amplitude")
plt.show()
